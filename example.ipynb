# %%
from engin import Auto_forecast
from engin.demo import load_demo_data

data = load_demo_data()
result = Auto_forecast(data[0])
result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 from src.engin import Auto_forecast
#       2 from src.engin.demo import load_demo_data
# ----> 4 data = load_demo_data()
#       5 result = Auto_forecast(data[0])
#       6 result
#
# File ~/Documents/Аспирантура/Диссертация/Programs/Stepwise Forecast Constructor/src/engin/demo.py:9, in load_demo_data()
#       4 def load_demo_data():
#       5     """
#       6     Загружает демонстрационные данные,
#       7     поставляемые вместе с пакетом.
#       8     """
# ----> 9     with resources.files("engin").joinpath(
#      10         "data/data_for_test.json"
#      11     ).open("r", encoding="utf-8") as f:
#      12         return json.load(f)
#
# File /opt/anaconda3/lib/python3.11/importlib/resources/_common.py:22, in files(package)
#      17 def files(package):
# ...

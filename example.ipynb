# %%
import json
import engin

# %%
with open('/Users/daniil/Documents/Аспирантура/Диссертация/Programs/Stepwise Forecast Constructor/data_for_test.json', "r", encoding="utf8") as f:
    data = json.load(f)

# %%
engin.Auto_forecast(data[1])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:7697: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)
#           Дата         Шаги Модель   Прогноз
# 0   31.08.2025   Горизонт 1     RW  27821.44
# 1   30.09.2025   Горизонт 2     RW  27821.44
# 2   31.10.2025   Горизонт 3    RWD  28137.43
# 3   30.11.2025   Горизонт 4    RWD  28242.75
# 4   31.12.2025   Горизонт 5    RWD  28348.08
# 5   31.01.2026   Горизонт 6    RWD  28453.41
# 6   28.02.2026   Горизонт 7    RWD  28558.74
# 7   31.03.2026   Горизонт 8     TS  30640.48
# 8   30.04.2026   Горизонт 9     TS  30761.59
# 9   31.05.2026  Горизонт 10     TS  30882.70
# 10  30.06.2026  Горизонт 11     TS  31003.80
# 11  31.07.2026  Горизонт 12     TS  31124.91
